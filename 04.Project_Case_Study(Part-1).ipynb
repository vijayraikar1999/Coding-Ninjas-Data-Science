# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem-1
# <img src ='04.Project-Case Study(Part-1)/1. Dataset Details.png'>

# %%
df = pd.read_csv('04.Project-Case Study(Part-1)/startup_funding.csv').copy()

# %%
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
df.shape
# Out:
# (2372, 10)

# %% [markdown]
# <p style="font-size:120%; color:green">1.Types of Startups that are getting funded in last few years<p>

# %%
df.AmountInUSD.fillna('0', inplace = True)

# %% [markdown]
# ### Solution.

# %%
df[df.AmountInUSD != '0']
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# 5        5  01/07/2017     Billion Loans  Consumer Internet
# 6        6  03/07/2017  Ecolibriumenergy         Technology
# ...    ...         ...               ...                ...
# 2366  2366  28/01/2015     Grabhouse.com                NaN
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                SubVertical CityLocation  \
# 0                 Predictive Care Platform    Bangalore
# 3                   DIY Ecommerce platform       Mumbai
# 4            healthcare service aggregator    Hyderabad
# ...

# %% [markdown]
# <p style="font-size:120%; color:green">2. Who are the important investors?<p>
# <p>Important investors are those who are giving fund more than or equal to the <b>mean</b> of all the funding amounts.</p>

# %% [markdown]
# ### Solution.

# %%
df.describe()
# Out:
#                SNo
# count  2372.000000
# mean   1185.500000
# std     684.881742
# min       0.000000
# 25%     592.750000
# 50%    1185.500000
# 75%    1778.250000
# max    2371.000000

# %%
df
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# ...

# %%
def changeToInt(s):
    return float(s.replace(',', ''))

# %%
df['AmountInUSdollor'] = df.AmountInUSD.apply(changeToInt)

# %%
df
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# ...

# %%
del df['AmountInUSD']

# %%
df
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# ...

# %%
df.describe()
# Out:
#                SNo  AmountInUSdollor
# count  2372.000000      2.372000e+03
# mean   1185.500000      7.734986e+06
# std     684.881742      5.165832e+07
# min       0.000000      0.000000e+00
# 25%     592.750000      0.000000e+00
# 50%    1185.500000      3.000000e+05
# 75%    1778.250000      2.500000e+06
# max    2371.000000      1.400000e+09

# %%
df[df.AmountInUSdollor >= df.AmountInUSdollor.mean()]
# Out:
#        SNo        Date    StartupName   IndustryVertical  \
# 7        7  04/07/2017          Droom          eCommerce
# 8        8  05/07/2017      Jumbotail          eCommerce
# 9        9  05/07/2017         Moglix          eCommerce
# 19      19  12/07/2017       Innoviti         Technology
# 31      31  19/07/2017      Rentomojo  Consumer Internet
# ...    ...         ...            ...                ...
# 2350  2350  20/01/2015      Hopscotch                NaN
# 2353  2353  21/01/2015    Simplilearn                NaN
# 2360  2360  22/01/2015         Antuit                NaN
# 2361  2361  22/01/2015  Caratlane.com                NaN
# 2365  2365  27/01/2015   CarDekho.com                NaN
#
#                                   SubVertical CityLocation  \
# 7          Online marketplace for automobiles      Gurgaon
# 8     online marketplace for food and grocery    Bangalore
# 9     B2B marketplace for Industrial products        Noida
# ...

# %% [markdown]
# ##### Ans.

# %%
df[df.AmountInUSdollor >= df.AmountInUSdollor.mean()].InvestorsName
# Out:
# 7         Asset Management (Asia) Ltd, Digital Garage Inc
# 8           Kalaari Capital, Nexus India Capital Advisors
# 9       International Finance Corporation, Rocketship,...
# 19      SBI-FMO Fund, Bessemer Venture Partners, Catam...
# 31                 ain Capital Ventures, Renaud Laplanche
#                               ...
# 2350                      Eduardo Saverin & Velos Capital
# 2353     Mayfield India, Kalaari Capital, Helion Ventures
# 2360                        Goldman Sachs, Zodius Capital
# 2361                                         Tiger Global
# 2365                  Hillhouse Capital, Tybourne Capital
# Name: InvestorsName, Length: 327, dtype: object

# %% [markdown]
# <p style="font-size:120%; color:green">3.What are the hot fields that are getting a lot of funding these days?<p>
# <p>These are those fields which are getting funding more than the mean of all the funding amounts.</p>

# %% [markdown]
# ### Solution.

# %%
df1 = df[df.AmountInUSdollor >= df.AmountInUSdollor.mean()]
df1[df1['IndustryVertical'].notna()]
# Out:
#        SNo        Date      StartupName             IndustryVertical  \
# 7        7  04/07/2017            Droom                    eCommerce
# 8        8  05/07/2017        Jumbotail                    eCommerce
# 9        9  05/07/2017           Moglix                    eCommerce
# 19      19  12/07/2017         Innoviti                   Technology
# 31      31  19/07/2017        Rentomojo            Consumer Internet
# ...    ...         ...              ...                          ...
# 2179  2179  23/04/2015     Craftstvilla     Ethnic Product eCommerce
# 2185  2185  24/04/2015         Coverfox  Online Insurance Aggregator
# 2190  2190  28/04/2015         Babajobs        Grey collar Job Board
# 2193  2193  28/04/2015      Naaptol.com    Tele-Shopping / eCommerce
# 2200  2200  29/04/2015  Travel Triangle    Online Travel Marketplace
#
#                                   SubVertical CityLocation  \
# 7          Online marketplace for automobiles      Gurgaon
# ...

# %% [markdown]
# ## Problem-2
# <img src ='04.Project-Case Study(Part-1)/2. Number of Fundings.png'>

# %% [markdown]
# <p style="font-size:120%; color:green">1.Total number of funding in each year.<p>

# %%
df
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# ...

# %%
df.loc[0].Date
# Out:
# '01/08/2017'

# %% [markdown]
# ### Solution.

# %%
df1 = df[df.AmountInUSdollor > 0]
df1
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# 5        5  01/07/2017     Billion Loans  Consumer Internet
# 6        6  03/07/2017  Ecolibriumenergy         Technology
# ...    ...         ...               ...                ...
# 2366  2366  28/01/2015     Grabhouse.com                NaN
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                SubVertical CityLocation  \
# 0                 Predictive Care Platform    Bangalore
# 3                   DIY Ecommerce platform       Mumbai
# 4            healthcare service aggregator    Hyderabad
# ...

# %%
dateSeries = df1['Date']

# %%
dateSeries
# Out:
# 0       01/08/2017
# 3       02/08/2017
# 4       02/08/2017
# 5       01/07/2017
# 6       03/07/2017
#            ...
# 2366    28/01/2015
# 2367    29/01/2015
# 2368    29/01/2015
# 2369    30/01/2015
# 2371    31/01/2015
# Name: Date, Length: 1525, dtype: object

# %%
type(dateSeries)
# Out:
# pandas.core.series.Series

# %%
ansDict = {}
for date in dateSeries:
    ansDict[date[-4:]] = ansDict.get(date[-4:], 0) + 1

# %% [markdown]
# #### Ans.

# %%
ansDict
# Out:
# {'2017': 285, '2016': 586, '2015': 654}

# %% [markdown]
# <p style="font-size:120%; color:green">2.Graph between years and fundings.<p>

# %%
years = [2015, 2016, 2017]
fundings = [ansDict['2015'], ansDict['2016'], ansDict['2017']]

# %%
plt.plot(years, fundings)
plt.xlabel('Years')
plt.ylabel('Fundings')
plt.axis([2013, 2019, 0, 700])
plt.show()

# %%
for i in range(2015, 2018):
    print(i, '-', ansDict[str(i)])
# Out:
# 2015 - 654
# 2016 - 586
# 2017 - 285
